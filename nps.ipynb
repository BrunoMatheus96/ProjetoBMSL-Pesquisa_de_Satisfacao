# %% [markdown]
# # Problema de Negócio
# 📝Identificar fatores que influenciam a satisfação dos passageiros.

# %% [markdown]
# ## Libs

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# ## Carregando o DataSet

# %%
nps = pd.read_csv('NPS.csv')

# %% [markdown]
# ## Explorando o DataSet

# %%
nps.shape
# Out:
# (103904, 25)

# %%
nps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
#  11  Gate location                      103904 non-null  int64
#  12  Food and drink                     103904 non-null  int64
#  13  Online boarding                    103904 non-null  int64
#  14  Seat comfort                       103904 non-null  int64
#  15  Inflight entertainment             103904 non-null  int64
#  16  On-board service                   103904 non-null  int64
#  17  Leg room service                   103904 non-null  int64
#  18  Baggage handling                   103904 non-null  int64
#  19  Checkin service                    103904 non-null  int64
#  20  Inflight service                   103904 non-null  int64
#  21  Cleanliness                        103904 non-null  int64
#  22  Departure Delay in Minutes         103904 non-null  int64
#  23  Arrival Delay in Minutes           103594 non-null  float64
#  24  satisfaction                       103904 non-null  object
# dtypes: float64(1), int64(19), object(5)
# memory usage: 19.8+ MB

# %%
nps.sample(10)
# Out:
#        Unnamed: 0      id  Gender   Customer Type  Age   Type of Travel  \
# 7718         7718   47865    Male  Loyal Customer   22  Business travel
# 14103       14103   60174  Female  Loyal Customer   37  Personal Travel
# 81508       81508  117836    Male  Loyal Customer   40  Business travel
# 59910       59910    8800    Male  Loyal Customer   60  Business travel
# 45277       45277   40601    Male  Loyal Customer   67  Personal Travel
# 90497       90497    8339  Female  Loyal Customer   41  Business travel
# 75413       75413   88805  Female  Loyal Customer   60  Business travel
# 15557       15557   82297  Female  Loyal Customer   52  Business travel
# 86120       86120   45958    Male  Loyal Customer   56  Business travel
# 20411       20411   70562    Male  Loyal Customer   52  Business travel
#
#           Class  Flight Distance  Inflight wifi service  \
# 7718   Business             2042                      2
# 14103       Eco             1120                      2
# 81508  Business             2878                      5
# 59910  Business             2823                      1
# 45277       Eco              391                      5
# 90497  Business             2812                      3
# 75413  Business             3641                      1
# 15557  Business              986                      5
# 86120  Eco Plus              409                      3
# 20411       Eco              858                      4
#
#        Departure/Arrival time convenient  ...  Inflight entertainment  \
# 7718                                   1  ...                       2
# 14103                                  4  ...                       4
# 81508                                  5  ...                       5
# 59910                                  1  ...                       5
# 45277                                  4  ...                       3
# 90497                                  3  ...                       3
# 75413                                  1  ...                       4
# 15557                                  5  ...                       4
# 86120                                  5  ...                       3
# 20411                                  4  ...                       5
#
#        On-board service  Leg room service  Baggage handling  Checkin service  \
# 7718                  1                 1                 3                4
# 14103                 3                 5                 5                5
# 81508                 5                 5                 5                4
# 59910                 5                 5                 5                3
# 45277                 3                 5                 4                3
# 90497                 3                 3                 3                2
# 75413                 4                 4                 4                4
# 15557                 4                 4                 4                3
# 86120                 1                 5                 3                3
# 20411                 1                 2                 2                4
#
#        Inflight service  Cleanliness  Departure Delay in Minutes  \
# 7718                  3            2                           0
# 14103                 5            4                           2
# 81508                 5            5                           0
# 59910                 5            4                           0
# 45277                 4            3                           0
# 90497                 3            4                           0
# 75413                 4            5                           0
# 15557                 4            5                           0
# 86120                 4            3                           6
# 20411                 4            5                           0
#
#        Arrival Delay in Minutes             satisfaction
# 7718                        0.0  neutral or dissatisfied
# 14103                       2.0  neutral or dissatisfied
# 81508                       0.0                satisfied
# 59910                       0.0                satisfied
# 45277                       0.0                satisfied
# 90497                       0.0  neutral or dissatisfied
# 75413                       0.0                satisfied
# 15557                       0.0                satisfied
# 86120                       6.0  neutral or dissatisfied
# 20411                       0.0                satisfied
#
# [10 rows x 25 columns]

# %% [markdown]
# ## Explorando o DataFrame

# %%
df_nps = nps.copy()

# %%
df_nps.shape
# Out:
# (103904, 25)

# %%
df_nps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
#  11  Gate location                      103904 non-null  int64
#  12  Food and drink                     103904 non-null  int64
#  13  Online boarding                    103904 non-null  int64
#  14  Seat comfort                       103904 non-null  int64
#  15  Inflight entertainment             103904 non-null  int64
#  16  On-board service                   103904 non-null  int64
#  17  Leg room service                   103904 non-null  int64
#  18  Baggage handling                   103904 non-null  int64
#  19  Checkin service                    103904 non-null  int64
#  20  Inflight service                   103904 non-null  int64
#  21  Cleanliness                        103904 non-null  int64
#  22  Departure Delay in Minutes         103904 non-null  int64
#  23  Arrival Delay in Minutes           103594 non-null  float64
#  24  satisfaction                       103904 non-null  object
# dtypes: float64(1), int64(19), object(5)
# memory usage: 19.8+ MB

# %%
df_nps.sample(20)
# Out:
#        Unnamed: 0      id  Gender   Customer Type  Age   Type of Travel  \
# 19933       19933  123341    Male  Loyal Customer   55  Personal Travel
# 18838       18838   14499    Male  Loyal Customer   28  Business travel
# 62506       62506   44863  Female  Loyal Customer   51  Business travel
# 89677       89677   62423  Female  Loyal Customer   50  Business travel
# 72839       72839  129344    Male  Loyal Customer   64  Personal Travel
# 48998       48998   81479    Male  Loyal Customer   41  Business travel
# 79277       79277   14383  Female  Loyal Customer   51  Business travel
# 12469       12469  110628  Female  Loyal Customer   32  Personal Travel
# 82476       82476   74070    Male  Loyal Customer   26  Business travel
# 24239       24239   94949  Female  Loyal Customer   38  Business travel
# 83043       83043   92967    Male  Loyal Customer   26  Personal Travel
# 47202       47202   26760  Female  Loyal Customer   42  Personal Travel
# 60386       60386   73678  Female  Loyal Customer   35  Business travel
# 57023       57023   55846    Male  Loyal Customer   50  Personal Travel
# 62288       62288   75137  Female  Loyal Customer   53  Business travel
# 98802       98802   35077  Female  Loyal Customer   17  Personal Travel
# 88468       88468  123778  Female  Loyal Customer   40  Business travel
# 28751       28751   40563    Male  Loyal Customer   46  Business travel
# 14552       14552   77905  Female  Loyal Customer   30  Personal Travel
# 15251       15251  122925    Male  Loyal Customer   22  Personal Travel
#
#           Class  Flight Distance  Inflight wifi service  \
# 19933  Eco Plus              631                      3
# 18838       Eco              402                      5
# 62506  Eco Plus              693                      5
# 89677  Business             1911                      3
# 72839       Eco             2586                      2
# 48998  Business              528                      3
# 79277  Business             3319                      2
# 12469       Eco              727                      4
# 82476  Business             2329                      4
# 24239  Business              248                      3
# 83043       Eco             1694                      1
# 47202       Eco              859                      2
# 60386  Business             1753                      0
# 57023       Eco             1416                      3
# 62288  Business             1846                      2
# 98802  Business             1069                      2
# 88468  Business              544                      1
# 28751       Eco              216                      4
# 14552       Eco              456                      0
# 15251  Business              631                      3
#
#        Departure/Arrival time convenient  ...  Inflight entertainment  \
# 19933                                  2  ...                       3
# 18838                                  5  ...                       5
# 62506                                  1  ...                       5
# 89677                                  3  ...                       4
# 72839                                  4  ...                       1
# 48998                                  1  ...                       3
# 79277                                  1  ...                       2
# 12469                                  2  ...                       4
# 82476                                  4  ...                       4
# 24239                                  4  ...                       3
# 83043                                  5  ...                       2
# 47202                                  5  ...                       5
# 60386                                  5  ...                       5
# 57023                                  1  ...                       1
# 62288                                  2  ...                       5
# 98802                                  4  ...                       4
# 88468                                  1  ...                       5
# 28751                                  4  ...                       4
# 14552                                  2  ...                       3
# 15251                                  5  ...                       2
#
#        On-board service  Leg room service  Baggage handling  Checkin service  \
# 19933                 1                 4                 1                2
# 18838                 1                 2                 4                3
# 62506                 5                 5                 5                4
# 89677                 4                 4                 4                5
# 72839                 1                 1                 3                4
# 48998                 3                 3                 3                4
# 79277                 2                 3                 2                4
# 12469                 2                 1                 3                4
# 82476                 4                 2                 5                5
# 24239                 3                 3                 3                4
# 83043                 1                 5                 5                1
# 47202                 5                 1                 5                5
# 60386                 5                 5                 5                3
# 57023                 2                 5                 3                2
# 62288                 5                 5                 5                5
# 98802                 2                 5                 4                4
# 88468                 5                 5                 5                3
# 28751                 5                 5                 3                2
# 14552                 3                 1                 4                3
# 15251                 3                 4                 4                4
#
#        Inflight service  Cleanliness  Departure Delay in Minutes  \
# 19933                 2            3                           0
# 18838                 2            5                           0
# 62506                 5            2                           0
# 89677                 4            3                           0
# 72839                 4            1                           8
# 48998                 3            3                           0
# 79277                 2            4                          57
# 12469                 3            4                           0
# 82476                 4            4                          22
# 24239                 3            1                          27
# 83043                 3            2                          11
# 47202                 5            3                           3
# 60386                 5            4                           0
# 57023                 2            1                           0
# 62288                 5            4                           3
# 98802                 5            4                           0
# 88468                 5            3                           0
# 28751                 4            4                           0
# 14552                 4            3                           3
# 15251                 5            2                           0
#
#        Arrival Delay in Minutes             satisfaction
# 19933                       0.0  neutral or dissatisfied
# 18838                       0.0                satisfied
# 62506                      57.0                satisfied
# 89677                       0.0                satisfied
# 72839                       1.0  neutral or dissatisfied
# 48998                       0.0  neutral or dissatisfied
# 79277                      69.0  neutral or dissatisfied
# 12469                       0.0  neutral or dissatisfied
# 82476                       5.0                satisfied
# 24239                      23.0  neutral or dissatisfied
# 83043                       4.0  neutral or dissatisfied
# 47202                      10.0  neutral or dissatisfied
# 60386                       0.0                satisfied
# 57023                       0.0  neutral or dissatisfied
# 62288                       0.0                satisfied
# 98802                       0.0  neutral or dissatisfied
# 88468                       0.0                satisfied
# 28751                       0.0                satisfied
# 14552                       0.0                satisfied
# 15251                       0.0  neutral or dissatisfied
#
# [20 rows x 25 columns]

# %% [markdown]
# 🔎Verificando valores ausentes

# %%
df_nps.isnull().sum().sort_values(ascending = False)
# Out:
# Arrival Delay in Minutes             310
# Unnamed: 0                             0
# Online boarding                        0
# Departure Delay in Minutes             0
# Cleanliness                            0
# Inflight service                       0
# Checkin service                        0
# Baggage handling                       0
# Leg room service                       0
# On-board service                       0
# Inflight entertainment                 0
# Seat comfort                           0
# Food and drink                         0
# id                                     0
# Gate location                          0
# Ease of Online booking                 0
# Departure/Arrival time convenient      0
# Inflight wifi service                  0
# Flight Distance                        0
# Class                                  0
# Type of Travel                         0
# Age                                    0
# Customer Type                          0
# Gender                                 0
# satisfaction                           0
# dtype: int64

# %%
valores_ausentes = df_nps.isnull().sum().sort_values(ascending = False)

valores_ausentes_percent = valores_ausentes[valores_ausentes > 0] / df_nps.shape[0] 

# Imprimir corretamente os valores de porcentagem
for coluna, valor in valores_ausentes_percent.items():
    print(f'{coluna}: {valor * 100:.2f}%')
# Out:
# Arrival Delay in Minutes: 0.30%

# %% [markdown]
# 🔎Verificando valores duplicados

# %%
df_nps.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 🔎Verificando Outliers
